# %%
print("Привет, мир")
# Out:
# Привет, мир

# %%
print("Строка 1")
print("Строка 2")
print("Строка 3")
# Out:
# Строка 1
# Строка 2
# Строка 3

# %% [markdown]
# Зачем нужен .venv (очень просто)
#
# Представь:
#
# один Python для системы другой — для проекта
#
# Чтобы не мешать их — делают виртуальное окружение.

# %% [markdown]
# mkdir - создане папки
#
# python -m venv .venv - создание вертуального окуружение
